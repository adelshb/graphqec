# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import numpy as np
import matplotlib.pyplot as plt

from graphqec import ShorCode, ThresholdLAB

# %%
shor = ShorCode(
    distance = 3,
    depolarize1_rate = 0.01,
    depolarize2_rate = 0.01
)

# shor.build_memory_circuit(number_of_rounds=1)
# shor.memory_circuit.diagram()

# %%
shor.draw_graph()

# %%
# th = ThresholdLAB(
#     distances= [3, 5, 7, 11],
#     code=ShorCode,
#     error_rates= np.linspace(0, 0.1, 10)
# )

# th.collect_stats(num_shots=10**4)

# %%
# th.plot_stats(
#     x_min = 3e-2, 
#     x_max = 1e-1,
#     y_min = 1e-3, 
#     y_max = 5e-1
# )
